# %%
import numpy as np
np.linalg.svd([[1, 2], [2, 4], [3, 6]])
# Out:
# SVDResult(U=array([[-0.26726124,  0.94816592,  0.17190932],
#        [-0.53452248,  0.00256504, -0.84515036],
#        [-0.80178373, -0.31776533,  0.50613047]]), S=array([8.36660027e+00, 7.32018325e-16]), Vh=array([[-0.4472136 , -0.89442719],
#        [-0.89442719,  0.4472136 ]]))
